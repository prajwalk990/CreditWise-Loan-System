# %%
import requests

# %%
URL = "https://www.scrapethissite.com/pages/simple/"
req = requests.get(URL)
html_data = req.text

# %%
req.content 
req.headers 
req.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_data,"lxml");
soup
with open("index2.html","w",encoding="utf-8") as f :
  f.write(html_data)

# %%
soup.find("h1" )
# Out:
# <h1>
#                             Countries of the World: A Simple Example
#                             <small>250 items</small>
# </h1>

# %%
df = []

# %%
for h3 in all_h3 : 
    country = (h3.get_text(strip=True))
    population = h3.find_next("div").select_one("span.country-population").get_text()
    area = h3.find_next("div").select_one("span.country-area").get_text()
    df.append([country,population,area])
df
# Out:
# [['Andorra', '84000', '468.0'],
#  ['United Arab Emirates', '4975593', '82880.0'],
#  ['Afghanistan', '29121286', '647500.0'],
#  ['Antigua and Barbuda', '86754', '443.0'],
#  ['Anguilla', '13254', '102.0'],
#  ['Albania', '2986952', '28748.0'],
#  ['Armenia', '2968000', '29800.0'],
#  ['Angola', '13068161', '1246700.0'],
#  ['Antarctica', '0', '1.4E7'],
#  ['Argentina', '41343201', '2766890.0'],
#  ['American Samoa', '57881', '199.0'],
#  ['Austria', '8205000', '83858.0'],
#  ['Australia', '21515754', '7686850.0'],
#  ['Aruba', '71566', '193.0'],
#  ['Åland', '26711', '1580.0'],
#  ['Azerbaijan', '8303512', '86600.0'],
#  ['Bosnia and Herzegovina', '4590000', '51129.0'],
#  ['Barbados', '285653', '431.0'],
#  ['Bangladesh', '156118464', '144000.0'],
#  ['Belgium', '10403000', '30510.0'],
#  ['Burkina Faso', '16241811', '274200.0'],
#  ['Bulgaria', '7148785', '110910.0'],
#  ['Bahrain', '738004', '665.0'],
#  ['Burundi', '9863117', '27830.0'],
#  ['Benin', '9056010', '112620.0'],
# ...

# %%
import pandas as pd 
data = pd.DataFrame(df,columns=["COUNTRY","POPULATION","AREA"])
# Out:
# 0                   Andorra
# 1      United Arab Emirates
# 2               Afghanistan
# 3       Antigua and Barbuda
# 4                  Anguilla
#                ...
# 245                   Yemen
# 246                 Mayotte
# 247            South Africa
# 248                  Zambia
# 249                Zimbabwe
# Name: COUNTRY, Length: 250, dtype: object

# %%
data.to_csv("cleaned_data.csv",index=False);
