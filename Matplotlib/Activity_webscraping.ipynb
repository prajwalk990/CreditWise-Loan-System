# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
URL = "https://quotes.toscrape.com/"
res = requests.get(URL)
text = res.text

# %%
soup = BeautifulSoup(text,"lxml")

# %%
 divs = soup.select_one(".quote")

# %%
ref = soup.find_all(class_="quote")

# %%
parent = soup.find_all(class_="quote")

# %%
for child in parent:
    tag_container = child.find_next(class_="tags")

    if tag_container:
        tags = tag_container.find_all("a")

        for tag in tags:
            if tag.get_text(strip=True) == "life":
                quote = child.find_next(class_="text").get_text(strip=True)
                all_quote.append(quote)

# %%
parent[0].children
# Out:
# <generator object Tag.children.<locals>.<genexpr> at 0x000001ACD9C9EF80>

# %%
t = parent[0]
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
# Out:
# ['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”']

# %%
url = "https://quotes.toscrape.com/page/1/"

# %%
import time

# %%
all_quote = [] 
for i in range(0,11):
    URL = f"https://quotes.toscrape.com/page/{i}/" 
    res = requests.get(URL)
    time.sleep(0.5)
    if(res.status_code == 200 ) :
         text = res.text 
    soup = BeautifulSoup(text,"lxml")
    parent = soup.find_all(class_="quote")
    for child in parent:
     tag_container = child.find_next(class_="tags")

     if tag_container:
        tags = tag_container.find_all("a")

        for tag in tags:
            if tag.get_text(strip=True) == "life":
                quote = child.find_next(class_="text").get_text(strip=True)
                all_quote.append(quote)

# %%
for i in all_quote :
    print(i) 
    print("---------------------------------------------------------------------------")
# Out:
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# ---------------------------------------------------------------------------
# “It is better to be hated for what you are than to be loved for what you are not.”
# ---------------------------------------------------------------------------
# ...
