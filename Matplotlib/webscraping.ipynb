# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
URL = "https://stephen-king-api.onrender.com/api/books"
req = requests.get(URL,timeout=10)

# %%
data_json = req.json()

# %%
import pandas as pd 
data = pd.json_normalize(data_json)

# %%
req = requests.get(URL)
if (req.status_code == 200 ):
  print("Success")
else :
  print ("Failed")
# Out:
# Success

# %%
import requests

response = requests.get("https://api.coinpaprika.com/v1/tickers/btc-bitcoin")
data = response.json()
data
#BTC coin api key 
import pandas as pd 
df = pd.json_normalize(data);
df
# Out:
#             id     name symbol  rank  total_supply  max_supply  beta_value  \
# 0  btc-bitcoin  Bitcoin    BTC     1      20057081    21000000    0.979371
#
#           first_data_at          last_updated  quotes.USD.price  ...  \
# 0  2010-07-17T00:00:00Z  2026-07-16T09:19:16Z      64093.342273  ...
#
#    quotes.USD.percent_change_1h  quotes.USD.percent_change_6h  \
# 0                          0.02                         -0.85
#
#    quotes.USD.percent_change_12h  quotes.USD.percent_change_24h  \
# 0                          -1.12                          -1.01
#
#    quotes.USD.percent_change_7d  quotes.USD.percent_change_30d  \
# 0                          1.82                              0
#
#    quotes.USD.percent_change_1y  quotes.USD.ath_price   quotes.USD.ath_date  \
# 0                             0         126173.177785  2025-10-06T19:00:40Z
#
#    quotes.USD.percent_from_price_ath
# 0                             -49.19
#
# [1 rows x 26 columns]

# %%
crypto_api_key = "https://api.messari.io/api/v1/assets/bitcoin/metrics"
url = "https://api.trongrid.io/wallet/createtransaction"
res_crypto= requests.get(url)
print(res_crypto)
print(type(res_crypto))
# data_crypto = res_crypto.json();
# data_crypto
r = res_crypto.json()

# %%
url = "https://www.google.com/search?q=cricket+score&rlz=1C1CHZN_enIN1134IN1134&oq=&gs_lcrp=EgZjaHJvbWUqCQgAECMYJxjqAjIJCAAQIxgnGOoCMgkIARAjGCcY6gIyCQgCECMYJxjqAjIJCAMQIxgnGOoCMgkIBBAjGCcY6gIyCQgFECMYJxjqAjIJCAYQIxgnGOoCMgkIBxAjGCcY6gLSAQkyMDM4ajBqMTWoAgiwAgHxBRD4wZujhe3j&sourceid=chrome&source=chrome.rb&ie=UTF-8"
data = requests.get(url)
html = data.text 
print(data.text)
with open("index.html","w",encoding="utf-8") as f :
    f.write(html)
